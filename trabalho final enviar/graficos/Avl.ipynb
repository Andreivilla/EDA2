# %%
import matplotlib.pyplot as plt

# %%
piorCasoValores = [0.000000, 1.000000, 5.000000, 9.000000, 14.800000, 21.600000, 29.200001, 35.400002, 42.799999, 51.200001, 59.799999, 69.199997, 78.599998, 87.800003, 97.199997, 105.099998, 114.500000, 124.900002, 136.199997, 147.000000, 158.399994, 169.600006, 180.600006, 191.600006, 203.600006, 214.100006, 224.300003, 234.600006, 246.000000, 257.799988, 268.700012, 280.000000, 291.899994, 304.899994, 317.399994, 329.899994, 342.200012, 355.399994, 368.399994, 381.299988, 394.700012, 407.899994, 420.600006, 433.100006, 446.000000, 458.500000, 471.500000, 484.799988, 498.000000, 510.700012, 523.099976, 535.500000, 548.900024, 562.200012, 575.900024, 589.200012, 602.500000, 615.299988, 628.500000, 642.000000, 655.299988, 668.200012, 680.799988, 693.900024, 707.200012, 720.000000, 733.299988, 747.400024, 761.200012, 776.400024, 790.900024, 805.900024, 820.299988, 832.799988, 846.799988, 861.400024, 876.799988, 890.700012, 904.400024, 918.299988, 935.299988, 950.200012, 964.799988, 979.599976, 994.200012, 1007.700012, 1022.099976, 1037.199951, 1052.000000, 1066.599976, 1078.699951, 1093.800049, 1109.000000, 1124.000000, 1139.300049, 1152.800049, 1168.199951, 1183.000000, 1197.699951, 1212.199951]
piorCasoIndice = [i for i in range(1,101)]

# %%
plt.plot(piorCasoIndice, piorCasoValores)
plt.grid()
plt.title("Pior caso AVL")
plt.xscale("log")
plt.xlabel("Numero de chaves")
plt.ylabel("Numero de Operações")
plt.savefig("PiorCasoAVL", format = "png")
plt.show()

# %%
casoMedio = [0.000000, 1.000000, 3.000000, 5.000000, 7.000000, 11.000000, 14.000000, 17.000000, 21.000000, 24.000000, 29.000000, 33.000000, 37.000000, 42.000000, 45.000000, 49.000000, 54.000000, 59.000000, 64.000000, 69.000000, 74.000000, 79.000000, 84.000000, 90.000000, 95.000000, 99.000000, 104.000000, 110.000000, 115.000000, 120.000000, 126.000000, 132.000000, 138.000000, 143.000000, 149.000000, 154.000000, 160.000000, 166.000000, 172.000000, 179.000000, 185.000000, 191.000000, 196.000000, 202.000000, 208.000000, 214.000000, 220.000000, 227.000000, 233.000000, 239.000000, 244.000000, 251.000000, 257.000000, 264.000000, 270.000000, 277.000000, 283.000000, 289.000000, 296.000000, 302.000000, 308.000000, 314.000000, 320.000000, 327.000000, 333.000000, 339.000000, 345.000000, 351.000000, 358.000000, 364.000000, 371.000000, 378.000000, 383.000000, 390.000000, 396.000000, 403.000000, 409.000000, 416.000000, 422.000000, 431.000000, 438.000000, 445.000000, 452.000000, 458.000000, 465.000000, 471.000000, 479.000000, 486.000000, 493.000000, 499.000000, 506.000000, 513.000000, 520.000000, 527.000000, 533.000000, 540.000000, 547.000000, 555.000000, 561.000000, 568.000000]
casoMedioIndice = [i for i in range(1,101)]

# %%
plt.plot(casoMedioIndice, casoMedio)
plt.grid()
plt.title("Caso medio AVL")
plt.xscale("log")
plt.xlabel("Numero de chaves")
plt.ylabel("Numero de Operações")
plt.savefig("CasoMedioAVL", format = "png")
plt.show()

# %%
plt.plot(casoMedioIndice, casoMedio, label = "Caso medio")
plt.plot(piorCasoIndice, piorCasoValores, label = "Pior caso")
plt.title("Comparação\nArvore AVL")
plt.legend()
plt.grid()
plt.xscale("log")
plt.xlabel("Numero de chaves")
plt.ylabel("Numero de Operações")
plt.savefig("ComparacaoAVL", format = "png")
plt.show()
