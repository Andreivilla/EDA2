# %%
import matplotlib.pyplot as plt

# %%
piorCasoValores = [0.000000, 1.000000, 5.000000, 9.800000, 14.800000, 18.799999, 23.799999, 29.299999, 34.799999, 40.500000, 47.000000, 53.599998, 59.000000, 63.599998, 68.800003, 76.000000, 81.900002, 88.900002, 94.199997, 102.000000, 107.800003, 115.099998, 119.800003, 126.199997, 132.699997, 140.000000, 145.699997, 151.399994, 159.300003, 165.500000, 171.399994, 178.500000, 183.500000, 190.699997, 196.800003, 203.300003, 209.300003, 217.399994, 223.100006, 230.500000, 236.800003, 244.800003, 250.399994, 257.299988, 261.700012, 269.200012, 274.100006, 280.700012, 286.299988, 295.299988, 301.299988, 308.299988, 316.299988, 325.899994, 331.100006, 337.600006, 342.899994, 350.500000, 355.700012, 363.000000, 369.000000, 376.100006, 381.500000, 388.600006, 396.100006, 403.600006, 409.500000, 416.299988, 421.200012, 429.100006, 435.200012, 440.799988, 446.100006, 454.200012, 460.299988, 466.500000, 471.000000, 481.500000, 485.600006, 491.700012, 497.000000, 506.899994, 512.799988, 518.500000, 525.000000, 534.200012, 540.700012, 547.000000, 552.400024, 559.799988, 564.299988, 572.299988, 577.700012, 585.900024, 591.799988, 598.200012, 605.500000, 613.000000, 619.500000, 625.799988]
piorCasoIndice = [i for i in range(1,101)]

# %%
plt.plot(piorCasoIndice, piorCasoValores)
plt.grid()
plt.title("Pior caso \nRubro Negra")
plt.xscale("log")
plt.xlabel("Numero de chaves")
plt.ylabel("Numero de Operações")
plt.savefig("PiorCasoRN", format = "png")
plt.show()

# %%
casoMedio = casoMedio = [0.000000, 1.000000, 3.000000, 5.000000, 7.000000, 9.000000, 11.000000, 13.000000, 16.000000, 20.000000, 22.000000, 25.000000, 26.000000, 28.000000, 32.000000, 34.000000, 36.000000, 39.000000, 43.000000, 45.000000, 49.000000, 50.000000, 53.000000, 56.000000, 59.000000, 61.000000, 63.000000, 68.000000, 70.000000, 73.000000, 76.000000, 78.000000, 80.000000, 83.000000, 86.000000, 89.000000, 91.000000, 94.000000, 97.000000, 100.000000, 103.000000, 106.000000, 109.000000, 110.000000, 113.000000, 115.000000, 117.000000, 120.000000, 124.000000, 127.000000, 130.000000, 135.000000, 138.000000, 141.000000, 143.000000, 145.000000, 148.000000, 150.000000, 154.000000, 157.000000, 159.000000, 161.000000, 164.000000, 169.000000, 171.000000, 174.000000, 177.000000, 179.000000, 181.000000, 184.000000, 185.000000, 188.000000, 191.000000, 194.000000, 196.000000, 198.000000, 201.000000, 202.000000, 204.000000, 207.000000, 211.000000, 214.000000, 216.000000, 220.000000, 223.000000, 226.000000, 229.000000, 231.000000, 233.000000, 235.000000, 239.000000, 241.000000, 243.000000, 246.000000, 249.000000, 253.000000, 256.000000, 259.000000, 261.000000, 263.000000]
casoMedioIndice = [i for i in range(1,101)]

# %%
plt.plot(casoMedioIndice, casoMedio)
plt.grid()
plt.title("Caso medio \nRubro Negro")
plt.xscale("log")
plt.xlabel("Numero de chaves")
plt.ylabel("Numero de Operações")
plt.savefig("CasoMedioRN", format = "png")
plt.show()

# %%
plt.plot(casoMedioIndice, casoMedio, label = "Caso medio")
plt.plot(piorCasoIndice, piorCasoValores, label = "Pior caso")
plt.title("Comparação\nArvore Rubro Negra")
plt.legend()
plt.grid()
plt.xscale("log")
plt.xlabel("Numero de chaves")
plt.ylabel("Numero de Operações")
plt.savefig("ComparacaoRN", format = "png")
plt.show()
